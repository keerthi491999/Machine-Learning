# %%
import pandas as pd

# %%
from google.colab import files

# %%
u=files.upload()
# Out:
#      <input type="file" id="files-7869851e-db9f-42e9-af15-058c009dda63" name="files[]" multiple disabled />
#      <output id="result-7869851e-db9f-42e9-af15-058c009dda63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Salary_Data.csv to Salary_Data.csv

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
X=df.iloc[:,0].values.reshape(-1,1)

# %%
Y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
l.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = l.predict(X_test)

# %%
Y_pred #predicted salaries
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
Y_test #real salaries
# Out:
# array([ 37731, 122391,  57081,  63218, 116969, 109431, 112635,  55794,
#         83088, 101302])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(X_train, Y_train, color = 'blue')
plt.plot(X_train, l.predict(X_train), color='red')
plt.title("Experience Vs Salary graph (Training set)")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(X_test, Y_test, color = 'blue')
plt.plot(X_train, l.predict(X_train), color='red')
plt.title("Experience Vs Salary graph (Test set)")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')
